# %% [markdown]
# # AishaKanwal Assignment | @7:04:34 Data Science with Python | Crash Course | DS-101 | اردو

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load/Read FAO dataset

# %%
food = pd.read_csv('FAOSTAT_data.csv')
food.head(2)
# Out:
#   Domain_Code                   Domain  Area_Code      Area  Element_Code  \
# 0         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 1         RFN  Fertilizers by Nutrient        165  Pakistan          5157
#
#             Element  Item_Code                             Item  Year_Code  \
# 0  Agricultural Use       3102      Nutrient nitrogen N (total)       1961
# 1  Agricultural Use       3103  Nutrient phosphate P2O5 (total)       1961
#
#    Year    Unit  Value Flag                                   Flag_Description
# 0  1961  tonnes  41659   Qm  Official data from questionnaires and/or natio...
# 1  1961  tonnes    500   Qm  Official data from questionnaires and/or natio...

# %% [markdown]
# ## looking at the mean, median, min and max values of dataset

# %%
food.describe()
# Out:
#        Area_Code  Element_Code    Item_Code    Year_Code         Year  \
# count      172.0         172.0   172.000000   172.000000   172.000000
# mean       165.0        5157.0  3102.970930  1990.784884  1990.784884
# std          0.0           0.0     0.812385    16.678775    16.678775
# min        165.0        5157.0  3102.000000  1961.000000  1961.000000
# 25%        165.0        5157.0  3102.000000  1976.750000  1976.750000
# 50%        165.0        5157.0  3103.000000  1991.000000  1991.000000
# 75%        165.0        5157.0  3104.000000  2005.000000  2005.000000
# max        165.0        5157.0  3104.000000  2019.000000  2019.000000
#
#               Value
# count  1.720000e+02
# mean   7.064396e+05
# std    9.709749e+05
# min    1.440000e+02
# 25%    2.615950e+04
# 50%    2.689255e+05
# 75%    9.193622e+05
# max    3.505356e+06

# %%
food.tail(5)
# Out:
#     Domain_Code                   Domain  Area_Code      Area  Element_Code  \
# 167         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 168         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 169         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 170         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 171         RFN  Fertilizers by Nutrient        165  Pakistan          5157
#
#               Element  Item_Code                             Item  Year_Code  \
# 167  Agricultural Use       3102      Nutrient nitrogen N (total)       2018
# 168  Agricultural Use       3104      Nutrient potash K2O (total)       2018
# 169  Agricultural Use       3104      Nutrient potash K2O (total)       2019
# 170  Agricultural Use       3102      Nutrient nitrogen N (total)       2019
# 171  Agricultural Use       3103  Nutrient phosphate P2O5 (total)       2019
#
#      Year    Unit    Value Flag  \
# ...

# %%
food1 = food.drop(['Flag_Description', 'Year_Code', 'Area'], axis=1)
food1.head(5)
# Out:
#   Domain_Code                   Domain  Area_Code  Element_Code  \
# 0         RFN  Fertilizers by Nutrient        165          5157
# 1         RFN  Fertilizers by Nutrient        165          5157
# 2         RFN  Fertilizers by Nutrient        165          5157
# 3         RFN  Fertilizers by Nutrient        165          5157
# 4         RFN  Fertilizers by Nutrient        165          5157
#
#             Element  Item_Code                             Item  Year    Unit  \
# 0  Agricultural Use       3102      Nutrient nitrogen N (total)  1961  tonnes
# 1  Agricultural Use       3103  Nutrient phosphate P2O5 (total)  1961  tonnes
# 2  Agricultural Use       3103  Nutrient phosphate P2O5 (total)  1962  tonnes
# 3  Agricultural Use       3102      Nutrient nitrogen N (total)  1962  tonnes
# 4  Agricultural Use       3102      Nutrient nitrogen N (total)  1963  tonnes
#
#    Value Flag
# 0  41659   Qm
# 1    500   Qm
# 2    210   Qm
# 3  41160   Qm
# 4  67620   Qm

# %%
food1.mean()
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_11396/796370503.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   food1.mean()
# Area_Code          165.000000
# Element_Code      5157.000000
# Item_Code         3102.970930
# Year              1990.784884
# Value           706439.558140
# dtype: float64

# %%
food1.value_counts(['Item_Code'])
# Out:
# Item_Code
# 3102         59
# 3103         59
# 3104         54
# dtype: int64

# %%
food1.value_counts(['Area_Code'])
# Out:
# Area_Code
# 165          172
# dtype: int64

# %%
food1.value_counts(['Item'])
# Out:
# Item
# Nutrient nitrogen N (total)        59
# Nutrient phosphate P2O5 (total)    59
# Nutrient potash K2O (total)        54
# dtype: int64

# %%
food1.groupby(["Item"]).mean()
# Out:
#                                  Area_Code  Element_Code  Item_Code    Year  \
# Item
# Nutrient nitrogen N (total)          165.0        5157.0     3102.0  1990.0
# Nutrient phosphate P2O5 (total)      165.0        5157.0     3103.0  1990.0
# Nutrient potash K2O (total)          165.0        5157.0     3104.0  1992.5
#
#                                         Value
# Item
# Nutrient nitrogen N (total)      1.598544e+06
# Nutrient phosphate P2O5 (total)  4.414284e+05
# Nutrient potash K2O (total)      2.128265e+04

# %%
food1.groupby(["Item", 'Year']).mean()
# Out:
#                                   Area_Code  Element_Code  Item_Code    Value
# Item                        Year
# Nutrient nitrogen N (total) 1961      165.0        5157.0     3102.0  41659.0
#                             1962      165.0        5157.0     3102.0  41160.0
#                             1963      165.0        5157.0     3102.0  67620.0
#                             1964      165.0        5157.0     3102.0  84147.0
#                             1965      165.0        5157.0     3102.0  69242.0
# ...                                     ...           ...        ...      ...
# Nutrient potash K2O (total) 2015      165.0        5157.0     3104.0  25291.0
#                             2016      165.0        5157.0     3104.0  28954.0
#                             2017      165.0        5157.0     3104.0  54173.0
#                             2018      165.0        5157.0     3104.0  54173.0
#                             2019      165.0        5157.0     3104.0  47260.0
#
# ...

# %%
food1[food1['Value'] > 4000].mean()
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_11396/2337967564.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   food1[food1['Value'] > 4000].mean()
# Area_Code          165.000000
# Element_Code      5157.000000
# Item_Code         3102.896774
# Year              1993.245161
# Value           783764.219355
# dtype: float64

# %%
food1[food1['Value'] > 5000].mean()
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_11396/3160382803.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   food1[food1['Value'] > 5000].mean()
# Area_Code          165.000000
# Element_Code      5157.000000
# Item_Code         3102.896774
# Year              1993.245161
# Value           783764.219355
# dtype: float64

# %%
food1[food1['Value'] > 8000].mean()
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_11396/1899635032.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   food1[food1['Value'] > 8000].mean()
# Area_Code          165.000000
# Element_Code      5157.000000
# Item_Code         3102.882353
# Year              1993.450980
# Value           793921.921569
# dtype: float64

# %%
food1[food1['Value'] > 8000].groupby(["Item", 'Flag']).mean()
# Out:
#                                       Area_Code  Element_Code  Item_Code  \
# Item                            Flag
# Nutrient nitrogen N (total)     Fb        165.0        5157.0     3102.0
#                                 Fm        165.0        5157.0     3102.0
#                                 Qm        165.0        5157.0     3102.0
# Nutrient phosphate P2O5 (total) Fb        165.0        5157.0     3103.0
#                                 Fm        165.0        5157.0     3103.0
#                                 Qm        165.0        5157.0     3103.0
#                                 X         165.0        5157.0     3103.0
# Nutrient potash K2O (total)     Fm        165.0        5157.0     3104.0
#                                 Qm        165.0        5157.0     3104.0
#                                 W         165.0        5157.0     3104.0
#                                 X         165.0        5157.0     3104.0
#
# ...

# %%
food1[food1['Value'] > 6000].groupby(["Item", 'Flag']).mean()
# Out:
#                                       Area_Code  Element_Code  Item_Code  \
# Item                            Flag
# Nutrient nitrogen N (total)     Fb        165.0        5157.0     3102.0
#                                 Fm        165.0        5157.0     3102.0
#                                 Qm        165.0        5157.0     3102.0
# Nutrient phosphate P2O5 (total) Fb        165.0        5157.0     3103.0
#                                 Fm        165.0        5157.0     3103.0
#                                 Qm        165.0        5157.0     3103.0
#                                 X         165.0        5157.0     3103.0
# Nutrient potash K2O (total)     Fm        165.0        5157.0     3104.0
#                                 Qm        165.0        5157.0     3104.0
#                                 W         165.0        5157.0     3104.0
#                                 X         165.0        5157.0     3104.0
#
# ...

# %%
food1[food1['Value'] > 4000].groupby(["Item", 'Flag']).max()
# Out:
#                                      Domain_Code                   Domain  \
# Item                            Flag
# Nutrient nitrogen N (total)     Fb           RFN  Fertilizers by Nutrient
#                                 Fm           RFN  Fertilizers by Nutrient
#                                 Qm           RFN  Fertilizers by Nutrient
# Nutrient phosphate P2O5 (total) Fb           RFN  Fertilizers by Nutrient
#                                 Fm           RFN  Fertilizers by Nutrient
#                                 Qm           RFN  Fertilizers by Nutrient
#                                 X            RFN  Fertilizers by Nutrient
# Nutrient potash K2O (total)     Fm           RFN  Fertilizers by Nutrient
#                                 Qm           RFN  Fertilizers by Nutrient
#                                 W            RFN  Fertilizers by Nutrient
#                                 X            RFN  Fertilizers by Nutrient
#
# ...

# %%
food1[food1['Value'] > 4000].groupby(["Item", 'Flag']).min()
# Out:
#                                      Domain_Code                   Domain  \
# Item                            Flag
# Nutrient nitrogen N (total)     Fb           RFN  Fertilizers by Nutrient
#                                 Fm           RFN  Fertilizers by Nutrient
#                                 Qm           RFN  Fertilizers by Nutrient
# Nutrient phosphate P2O5 (total) Fb           RFN  Fertilizers by Nutrient
#                                 Fm           RFN  Fertilizers by Nutrient
#                                 Qm           RFN  Fertilizers by Nutrient
#                                 X            RFN  Fertilizers by Nutrient
# Nutrient potash K2O (total)     Fm           RFN  Fertilizers by Nutrient
#                                 Qm           RFN  Fertilizers by Nutrient
#                                 W            RFN  Fertilizers by Nutrient
#                                 X            RFN  Fertilizers by Nutrient
#
# ...
